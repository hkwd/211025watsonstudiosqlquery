# %%
#SQL Queryのライブラリー導入
# !pip install --upgrade ibmcloudsql
# Out:
# Requirement already up-to-date: ibmcloudsql in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (0.4.27)
# Requirement already satisfied, skipping upgrade: sqlparse>=0.4.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibmcloudsql) (0.4.2)
# Requirement already satisfied, skipping upgrade: ibm-cos-sdk-core>=2.7.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibmcloudsql) (2.7.0)
# Requirement already satisfied, skipping upgrade: backoff==1.10.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibmcloudsql) (1.10.0)
# Requirement already satisfied, skipping upgrade: typing-extensions in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibmcloudsql) (3.7.4.2)
# Requirement already satisfied, skipping upgrade: pandas>=1.3.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibmcloudsql) (1.3.4)
# Requirement already satisfied, skipping upgrade: ibm-cos-sdk>=2.7.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibmcloudsql) (2.7.0)
# Requirement already satisfied, skipping upgrade: isodate in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibmcloudsql) (0.6.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibmcloudsql) (1.6.1)
# Requirement already satisfied, skipping upgrade: numpy in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibmcloudsql) (1.19.2)
# Requirement already satisfied, skipping upgrade: pre-commit in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibmcloudsql) (2.15.0)
# Requirement already satisfied, skipping upgrade: pyarrow in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibmcloudsql) (3.0.0)
# Requirement already satisfied, skipping upgrade: packaging in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibmcloudsql) (20.4)
# Requirement already satisfied, skipping upgrade: requests>=2.2.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibmcloudsql) (2.22.0)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibm-cos-sdk-core>=2.7.0->ibmcloudsql) (0.15.2)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibm-cos-sdk-core>=2.7.0->ibmcloudsql) (2.8.1)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibm-cos-sdk-core>=2.7.0->ibmcloudsql) (0.9.4)
# Requirement already satisfied, skipping upgrade: pytz>=2017.3 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pandas>=1.3.0->ibmcloudsql) (2020.1)
# Requirement already satisfied, skipping upgrade: ibm-cos-sdk-s3transfer==2.7.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from ibm-cos-sdk>=2.7.0->ibmcloudsql) (2.7.0)
# Requirement already satisfied, skipping upgrade: six in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from isodate->ibmcloudsql) (1.15.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from importlib-metadata->ibmcloudsql) (3.1.0)
# Requirement already satisfied, skipping upgrade: cfgv>=2.0.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pre-commit->ibmcloudsql) (3.3.1)
# Requirement already satisfied, skipping upgrade: nodeenv>=0.11.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pre-commit->ibmcloudsql) (1.6.0)
# Requirement already satisfied, skipping upgrade: toml in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pre-commit->ibmcloudsql) (0.10.2)
# Requirement already satisfied, skipping upgrade: virtualenv>=20.0.8 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pre-commit->ibmcloudsql) (20.9.0)
# Requirement already satisfied, skipping upgrade: pyyaml>=5.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pre-commit->ibmcloudsql) (5.4.1)
# Requirement already satisfied, skipping upgrade: identify>=1.0.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pre-commit->ibmcloudsql) (2.3.1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from packaging->ibmcloudsql) (2.4.7)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests>=2.2.0->ibmcloudsql) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests>=2.2.0->ibmcloudsql) (2021.5.30)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests>=2.2.0->ibmcloudsql) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests>=2.2.0->ibmcloudsql) (1.25.9)
# Requirement already satisfied, skipping upgrade: platformdirs<3,>=2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from virtualenv>=20.0.8->pre-commit->ibmcloudsql) (2.4.0)
# Requirement already satisfied, skipping upgrade: backports.entry-points-selectable>=1.0.4 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from virtualenv>=20.0.8->pre-commit->ibmcloudsql) (1.1.0)
# Requirement already satisfied, skipping upgrade: filelock<4,>=3.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from virtualenv>=20.0.8->pre-commit->ibmcloudsql) (3.3.1)
# Requirement already satisfied, skipping upgrade: distlib<1,>=0.3.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from virtualenv>=20.0.8->pre-commit->ibmcloudsql) (0.3.3)

# %%
# @hidden_cell
# The following code contains the credentials for a connection in your Project.
# You might want to remove those credentials before you share your notebook.

from ibm_watson_studio_lib import access_project_or_space
wslib = access_project_or_space()
sqlquerya4_credentials = wslib.get_connection("sqlquerya4")

# %%
#資格情報の中身確認
import pprint
#pprint.pprint(sqlquerya4_credentials)

# %%
#SQL Queryへの接続
import ibmcloudsql
sqlClient = ibmcloudsql.SQLQuery(sqlquerya4_credentials['password'],
                                 sqlquerya4_credentials['crn'],
                                 sqlquerya4_credentials['target_cos_url'])

# %%
#クエリーの実行
query = """
select*
from COND4N_E104
"""

queryres = sqlClient.run_sql(query)

# %%
queryres.head()
# Out:
#    M_CD  UP_TIME  POWER  TEMP  ERR_CD
# 0   104       34   1003   244       0
# 1   104       35   1003   244       0
# 2   104       36   1003   244       0
# 3   104       37   1003   244       0
# 4   104       38    973   244       0

# %%
print(type(queryres))
# Out:
# <class 'pandas.core.frame.DataFrame'>
